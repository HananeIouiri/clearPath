# %%
# checking ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.80  Python-3.11.5 torch-2.6.0+cpu CPU (Intel Core(TM) i7-8565U 1.80GHz)
# Setup complete  (8 CPUs, 15.7 GB RAM, 215.6/475.9 GB disk)

# %%
import numpy as np
from ultralytics import YOLO
import random
import cv2

# %%
# Load a COCO-pretrained YOLOv8n model
# that will create a file called yolov8n that we will use later for prediction
model = YOLO("yolov8n.pt", "v8")

# Display model information (optional)
model.info()
# Out:
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# (129, 3157200, 0, 8.8575488)

# %%
#predict image
results = model.predict(source="images/img1.png", conf=0.25, save=True)
print(results[0].numpy())
# Out:
# image 1/1 c:\Users\Spectre\Desktop\ML\PI\YOLOv8_ObjectDetection\images\img1.png: 576x640 1 clock, 280.9ms
# Speed: 19.0ms preprocess, 280.9ms inference, 18.0ms postprocess per image at shape (1, 3, 576, 640)
# Results saved to runs\detect\predict2
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239],
#         ...,
#         [239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239]],
#
#        [[239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239],
#         ...,
#         [239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239]],
#
#        [[239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239],
#         ...,
#         [239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239]],
#
#        ...,
#
#        [[239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239],
#         ...,
#         [239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239]],
#
#        [[239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239],
#         ...,
#         [239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239]],
#
#        [[239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239],
#         ...,
#         [239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239]]], dtype=uint8)
# orig_shape: (1207, 1372)
# path: 'c:\\Users\\Spectre\\Desktop\\ML\\PI\\YOLOv8_ObjectDetection\\images\\img1.png'
# probs: None
# save_dir: None
# speed: {'preprocess': 18.965799994475674, 'inference': 280.85680000367574, 'postprocess': 17.96699999977136}
